# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pandasgui import show

# %%
df = pd.read_csv('traffic-accidents-annual2.csv')

# %%
df
# Out:
#         Place     Year  Total number of accidents  Fatal Accidents  \
# 0    Pakistan  2008-09                       9496             4145
# 1    Pakistan  2009-10                       9747             4378
# 2    Pakistan  2010-11                       9723             4280
# 3    Pakistan  2011-12                       9140             3966
# 4    Pakistan  2012-13                       8988             3884
# ..        ...      ...                        ...              ...
# 57  Islamabad  2014-15                        216              107
# 58  Islamabad  2015-16                        244              120
# 59  Islamabad  2016-17                        226              127
# 60  Islamabad  2017-18                        259              157
# 61  Islamabad  2018-19                        238              127
#
#     Non-Fatal Accidents  Killed  Injured  Total number of vehicles involved
# 0                  5351    4907    11037                              10322
# ...

# %%
df['Year'] = df['Year'].str.split("-").str[0]
df = df.explode('Year',ignore_index=True)
df
# Out:
#         Place  Year  Total number of accidents  Fatal Accidents  \
# 0    Pakistan  2008                       9496             4145
# 1    Pakistan  2009                       9747             4378
# 2    Pakistan  2010                       9723             4280
# 3    Pakistan  2011                       9140             3966
# 4    Pakistan  2012                       8988             3884
# ..        ...   ...                        ...              ...
# 57  Islamabad  2014                        216              107
# 58  Islamabad  2015                        244              120
# 59  Islamabad  2016                        226              127
# 60  Islamabad  2017                        259              157
# 61  Islamabad  2018                        238              127
#
#     Non-Fatal Accidents  Killed  Injured  Total number of vehicles involved
# 0                  5351    4907    11037                              10322
# ...

# %%
df.dtypes
# Out:
# Place                                object
# Year                                 object
# Total number of accidents             int64
# Fatal Accidents                       int64
# Non-Fatal Accidents                   int64
# Killed                                int64
# Injured                               int64
# Total number of vehicles involved     int64
# dtype: object

# %%
df['Year'] = df['Year'].astype("int")
df['Place'] = df['Place'].astype("string")

# %%
df.dtypes
# Out:
# Place                                string
# Year                                  int32
# Total number of accidents             int64
# Fatal Accidents                       int64
# Non-Fatal Accidents                   int64
# Killed                                int64
# Injured                               int64
# Total number of vehicles involved     int64
# dtype: object

# %%
show(df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
